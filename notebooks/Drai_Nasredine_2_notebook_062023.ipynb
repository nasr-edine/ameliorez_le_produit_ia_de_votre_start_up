# %% [markdown]
# # Improving the AI Product of Your Startup

# %% [markdown]
# ## Enhancing User Engagement and Insights through AI-driven Collaboration

# %% [markdown]
# - Notebook by [Nasr-edine DRAI](https://www.hackerrank.com/d_nasredine)
# - [Openclassrooms](https://openclassrooms.com/en/)

# %% [markdown]
# <div style="text-align:center;">
#     <img src="../../imgs/custom_seg.jpeg" width="400" />
# </div>

# %% [markdown]
# #### Introduction
#
# Welcome to the project "Improving the AI Product of Your Startup." In this project, you are an AI Engineer working for the startup "Avis Restau," which connects customers with restaurants. Your company aims to enhance its platform by introducing a new collaboration feature, allowing users to post reviews and photos of their favorite restaurants. Additionally, the company wants to gain better insights into the user-posted reviews.

# %% [markdown]
# #### Problem Statement and Objective
#
# The primary objective of this project is to conduct a feasibility study for two specific functionalities: detecting dissatisfaction topics in user comments and automatically labeling the photos posted on the platform. To achieve this, you need to analyze existing data and collect new data to train your AI models.

# %% [markdown]
# #### Overview of the Dataset
#
# The problem statement highlights that there is insufficient data available on the Avis Restau platform. Therefore, the solution is to utilize an existing dataset. The recommended dataset for this project is the Yelp dataset, which contains general information about restaurants, including consumer reviews. You can access the dataset through the following link: https://www.yelp.com/dataset

# %% [markdown]
# ### Get restaurants

# %%
import requests

url1 = "https://api.yelp.com/v3/businesses/search?sort_by=best_match&limit=50&offset=0&location=paris&term=restaurants"
url2 = "https://api.yelp.com/v3/businesses/search?sort_by=best_match&limit=50&offset=50&location=paris&term=restaurants"
url3 = "https://api.yelp.com/v3/businesses/search?sort_by=best_match&limit=50&offset=100&location=paris&term=restaurants"
url4 = "https://api.yelp.com/v3/businesses/search?sort_by=best_match&limit=50&offset=150&location=paris&term=restaurants"

filename = "Drai_Nasredine_1_csv_062023.csv"
path = "../data/"

payload={}
headers = {
  'Authorization': 'Bearer api_key'
}

test = 0
for url in [url1, url2, url3, url4]:
    response = requests.request("GET", url, headers=headers, data=payload)
    
    # print(response.text)
    data = json.loads(response.text)
    
    # CSV file path
    csv_file = path + filename
    
    # Open the CSV file in write mode
    with open(csv_file, mode='a', newline='') as file:
        # Create a CSV writer
        writer = csv.writer(file)
    
        # Write the header row
        if test == 0:
            writer.writerow(data['businesses'][0].keys())
            test = 1
    
        # Write each category as a row
        for category in data['businesses']:
            writer.writerow(category.values())
        file.close()
print("JSON data converted to CSV successfully.")
# Out:
# JSON data converted to CSV successfully.

# %%
import pandas as pd

# %%
restaurants = pd.read_csv(csv_file)
restaurants.head()
# Out:
#                        id                                alias  \
# 0  -0iLH7iQNYtoURciDpJf6w  le-comptoir-de-la-gastronomie-paris
# 1  IU9_wVOGBKjfqTTpAXpKcQ           bistro-des-augustins-paris
# 2  cEjF41ZQB8-SST8cd3EsEw             l-avant-comptoir-paris-3
# 3  wLgAxIB7111BcWLWh7KpFw                  la-régalade-paris-3
# 4  WHHt_Jb8Tgidn9mW7oDnIg               la-coïncidence-paris-4
#
#                             name  \
# 0  Le Comptoir de la Gastronomie
# 1           Bistro des Augustins
# 2               L'Avant Comptoir
# 3                    La Régalade
# 4                 La Coïncidence
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/xT4YkC...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/ctHDHM...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/mVwgxg...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/f_-Xgg...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/5O4QPn...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/le-comptoir-de-la-gas...          1240
# 1  https://www.yelp.com/biz/bistro-des-augustins-...           471
# 2  https://www.yelp.com/biz/l-avant-comptoir-pari...           649
# 3  https://www.yelp.com/biz/la-r%C3%A9galade-pari...           101
# 4  https://www.yelp.com/biz/la-co%C3%AFncidence-p...           509
#
#                                           categories  rating  \
# 0           [{'alias': 'french', 'title': 'French'}]     4.5
# 1  [{'alias': 'bistros', 'title': 'Bistros'}, {'a...     4.5
# 2  [{'alias': 'tapas', 'title': 'Tapas Bars'}, {'...     4.5
# 3           [{'alias': 'french', 'title': 'French'}]     4.5
# 4           [{'alias': 'french', 'title': 'French'}]     4.5
#
#                                          coordinates transactions price  \
# 0  {'latitude': 48.8645157999652, 'longitude': 2....           []    €€
# 1     {'latitude': 48.854754, 'longitude': 2.342119}           []    €€
# 2        {'latitude': 48.85202, 'longitude': 2.3388}           []    €€
# 3  {'latitude': 48.8616441182389, 'longitude': 2....           []   €€€
# 4     {'latitude': 48.868105, 'longitude': 2.284365}           []    €€
#
#                                             location         phone  \
# 0  {'address1': '34 rue Montmartre', 'address2': ...  +33142333132
# 1  {'address1': '39 quai des Grands Augustins', '...  +33143540441
# 2  {'address1': "3 carrefour de l'Odéon", 'addres...  +33142384755
# 3  {'address1': '106 rue Saint-Honoré', 'address2...  +33142219240
# 4  {'address1': '15 rue Mesnil', 'address2': '', ...  +33147559644
#
#        display_phone     distance
# 0  +33 1 42 33 31 32   370.827517
# 1  +33 1 43 54 04 41   801.117610
# 2  +33 1 42 38 47 55  1131.333887
# 3  +33 1 42 21 92 40    36.280480
# 4  +33 1 47 55 96 44  4281.588159

# %%
restaurants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             200 non-null    object
#  1   alias          200 non-null    object
#  2   name           200 non-null    object
#  3   image_url      200 non-null    object
#  4   is_closed      200 non-null    bool
#  5   url            200 non-null    object
#  6   review_count   200 non-null    int64
#  7   categories     200 non-null    object
#  8   rating         200 non-null    float64
#  9   coordinates    200 non-null    object
#  10  transactions   200 non-null    object
#  11  price          200 non-null    object
#  12  location       200 non-null    object
#  13  phone          195 non-null    object
#  14  display_phone  195 non-null    object
#  15  distance       173 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 23.8+ KB

# %%
restaurants.describe()
# Out:
#        review_count      rating     distance
# count    200.000000  200.000000   173.000000
# mean     143.145000    4.400000  1400.042778
# std      230.208522    0.343643  1043.869910
# min        1.000000    3.500000    21.830554
# 25%       25.000000    4.000000   587.329271
# 50%       63.500000    4.500000  1098.298811
# 75%      169.000000    4.500000  1945.426536
# max     1920.000000    5.000000  4724.525002

# %%
# Check for duplicate rows
duplicate_rows = restaurants.duplicated()

# Print the duplicate rows
restaurants[duplicate_rows]
# Out:
# Empty DataFrame
# Columns: [id, alias, name, image_url, is_closed, url, review_count, categories, rating, coordinates, transactions, price, location, phone, display_phone, distance]
# Index: []

# %% [markdown]
# ### Get Reviews

# %%
id = "-0iLH7iQNYtoURciDpJf6w"

import requests

url = f"https://api.yelp.com/v3/businesses/{id}/reviews"

payload={}
headers = {
  'Authorization': 'Bearer api_key'
}

response = requests.request("GET", url, headers=headers, data=payload)

# print(response.text)
data = json.loads(response.text)
data
# Out:
# {'reviews': [{'id': 'sok5mYZnawtFMhMO2qQl6w',
#    'url': 'https://www.yelp.com/biz/le-comptoir-de-la-gastronomie-paris?adjust_creative=lWGeH-LEHLA63JYPiK7UGw&hrid=sok5mYZnawtFMhMO2qQl6w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=lWGeH-LEHLA63JYPiK7UGw',
#    'text': 'Wow. What an amazing restaurant and a must try in Paris. \n\nRecommend:\nDuck Foie Gras Ravioli (10/10): Just amazing. The creamy sauce compliments the foie...',
#    'rating': 5,
#    'time_created': '2023-06-08 04:08:58',
#    'user': {'id': 'RSyuYG8RShnxGzM1jM3k5A',
#     'profile_url': 'https://www.yelp.com/user_details?userid=RSyuYG8RShnxGzM1jM3k5A',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/-0cwCaRAD4Aey5pNuFe3aA/o.jpg',
#     'name': 'Grace N.'}},
#   {'id': 'TqIYPVpx3BfIzawiCmeW8Q',
#    'url': 'https://www.yelp.com/biz/le-comptoir-de-la-gastronomie-paris?adjust_creative=lWGeH-LEHLA63JYPiK7UGw&hrid=TqIYPVpx3BfIzawiCmeW8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=lWGeH-LEHLA63JYPiK7UGw',
#    'text': 'Situated in the heart of Paris, on an assuming corner lies this gem of a restaurant. The store is not very large, sits at most 20 or so tables inside and...',
#    'rating': 5,
#    'time_created': '2023-05-18 10:49:15',
#    'user': {'id': '7QlwLXD9wryTTvv4ymjtXw',
#     'profile_url': 'https://www.yelp.com/user_details?userid=7QlwLXD9wryTTvv4ymjtXw',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/QCFGP3CGIHVdZLbI5XPvNA/o.jpg',
#     'name': 'Richard L.'}},
#   {'id': 'DvpQmef1WeUyQ18ysrFnIw',
#    'url': 'https://www.yelp.com/biz/le-comptoir-de-la-gastronomie-paris?adjust_creative=lWGeH-LEHLA63JYPiK7UGw&hrid=DvpQmef1WeUyQ18ysrFnIw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=lWGeH-LEHLA63JYPiK7UGw',
#    'text': "Great place. 90% of the guests are Asians (at least the time and day I was eating:730pm on a Tuesday) so i didn't feel out of place or anything like that....",
#    'rating': 5,
#    'time_created': '2023-05-17 01:56:17',
#    'user': {'id': 'Oe0q7E3SRHwe3shzGdoxyQ',
#     'profile_url': 'https://www.yelp.com/user_details?userid=Oe0q7E3SRHwe3shzGdoxyQ',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/4lLhqg0h51Kp_fekG7ar8A/o.jpg',
#     'name': 'Adrienne L.'}}],
#  'total': 1240,
#  'possible_languages': ['fr', 'en', 'es', 'it', 'pt', 'de', 'zh', 'ja', 'sv']}
